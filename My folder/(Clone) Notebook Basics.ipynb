# %%
print("Hello World")

# %%
# %sql
SELECT "hello world from sql";

# %% [markdown]
# # Title 1
# ## Title 2
#
# Images: ![Associate-badge](https://www.databricks.com/wp-content/uploads/2022/04/associate-badge-eng.svg)

# %%
print(_sqldf)

# %%
# %run ./Includes/Setup

# %%
print(full_name)

# %%
# %fs ls '/'

# %%
dbutils.fs.ls("dbfs:/databricks-datasets/")
